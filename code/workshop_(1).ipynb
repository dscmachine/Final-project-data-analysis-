# %% [markdown]
# # Insights:
# - 1. rate of female close to rate of male
# - 1. Young are majority of the customers
# - 2. 48.3 % from clients are partners (rate of partners close to rate of non-partners)
# - 3. 30% from clients are Dependents (non-Dependents are majority of the customers)
# - 4. more than 90% from clients use Phone Service , Phone Service is most used
# - 5. 48%  from clients have one line ( no.of customers who are used one line close to no.of customers who are used more one line)
# - 6. Approximately 50%  from clients are  not use online security
# - 7.Fiber optic is most used  in internt service
# - 8. Approximately 50%  from clients are  not use online Backup
# - 9. 43,94%  from clients are  not use device protection
# - 10. Approximately 50%  from clients are  not use tech support
# - 11. 55.02% from clients has contract month-to-mounth
# - 12. 60% from clients has parperlessbilling
# - 13. electronic check is most used in paymentway
# - 14. data is imbalance , no churn are majority
# - 15. 21.67% from clients are not used Internet Services which are ("InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Churn")
# - 16. 7% churned clients are not use internet services
# - 17. 78.33% clients use internet services ( majority of the customers use internet services)
# - 18. 31.83% churned clients use internet services
# - 19. 5.1% clients use internet services that use all services
# - 20. Approximately 5.28% churned clients are  use all internet services (can be neglected)
# - 21. Approximately 50% clients use internet services that use Streaming Movies ,Streaming Movies is most used in Internet Services
# - 22. 20 % clients use internet services that use 4 Services (where that using 4 internet services is most commmon)
# - 23. majority of churned clients use 2 internet services
# - 24. Approximately Young of female equal Young of male
# - 25. majority Dependents of clients are non-Partner
# - 26. clients use internet services that use 4 Services are higher range in TotalCharges
# - 27. TotalCharges increase by tenure
# - 28. MonthlyCharges of churn customers are relatively higher than non-churn customers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# upload data
data=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data['TotalCharges']= pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data['TotalCharges'].isna().sum()
# Out:
# 11

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['gender'].value_counts()
# Out:
# Male      3549
# Female    3483
# Name: gender, dtype: int64

# %%
sns.countplot(x=data['gender'])

# %%
def countplot_ratio(x,data,hue=None,ax=None):
    
    ax=sns.countplot(x,data=data,hue=hue,ax=ax)
    ax.set_xticklabels(ax.get_xticklabels())
    ax.set_title(x + " Distributions")
    
    total = float(len(data))
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,height + 3,
                '{:.2f}%'.format((height/total)*100),fontsize=12, weight = 'bold',ha="center") 

        
# rate of female close to rate of male
countplot_ratio(x=data.columns[1],data=data)

# %%
sns.scatterplot(x='gender',y='TotalCharges',data=data)

# %%
sns.swarmplot(x='gender',y='TotalCharges',hue='Churn',data=data)

# %%
countplot_ratio(x=data.columns[2],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#Approximately Young of female equal Young of male
countplot_ratio(x="SeniorCitizen",hue='gender',data=data)

# %%
sns.scatterplot(x="SeniorCitizen",y='TotalCharges',hue='gender',data=data)

# %%
# 48.3 % from clients are partners
countplot_ratio(x=data.columns[3],data=data)

# %%
# 30% from clients are Dependents
countplot_ratio(x=data.columns[4],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#majorty Dependents of cilents are non-Partner
countplot_ratio(x='Partner',hue='Dependents',data=data)

# %%
# more than 90% from clients use Phone Service , Phone Service is most used
countplot_ratio(x=data.columns[6],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
# 48%  from clients have one line
countplot_ratio(x=data.columns[7],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#Approximately 50%  from clients are  not use online security
countplot_ratio(x=data.columns[9],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
# Fiber optic is most used  in internt service
countplot_ratio(x=data.columns[8],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#Approximately 50%  from clients are  not use online Backup
countplot_ratio(x=data.columns[10],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#43,94%  from clients are  not use device protection
countplot_ratio(x=data.columns[11],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#Approximately 50%  from clients are  not use tech support
countplot_ratio(x=data.columns[12],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
countplot_ratio(x=data.columns[13],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
countplot_ratio(x=data.columns[14],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#55.02% from clients has contract month-to-mounth
countplot_ratio(x=data.columns[15],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#60% from clients has parper less billing
countplot_ratio(x=data.columns[16],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
#electronic check is most used in paymentway
countplot_ratio(x=data.columns[17],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
# data is imbalance , no churn 
countplot_ratio(x=data.columns[20],data=data)
# Out:
# No handles with labels found to put in legend.

# %%
countplot_ratio(x="InternetService",hue="OnlineSecurity",data=data)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
countplot_ratio(x="InternetService",hue="OnlineBackup",data=data)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# 21.67% from clients are not used Internet Services which are 
df_internet_service = data[["InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Churn"]]
df_internet_service
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# 1                DSL            Yes           No              Yes          No
# 2                DSL            Yes          Yes               No          No
# 3                DSL            Yes           No              Yes         Yes
# 4        Fiber optic             No           No               No          No
# ...              ...            ...          ...              ...         ...
# 7038             DSL            Yes           No              Yes         Yes
# 7039     Fiber optic             No          Yes              Yes          No
# 7040             DSL            Yes           No               No          No
# 7041     Fiber optic             No           No               No          No
# 7042     Fiber optic            Yes           No              Yes         Yes
#
# ...

# %%
df_internet_service.groupby('InternetService').count()
# Out:
#                  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# InternetService
# DSL                        2416          2416              2416         2416
# Fiber optic                3096          3096              3096         3096
# No                         1520          1520              1520         1520
#
#                  StreamingTV  StreamingMovies  Churn
# InternetService
# DSL                     2416             2416   2416
# Fiber optic             3096             3096   3096
# No                      1520             1520   1520

# %%
df_internet_service['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
# 21.67% clients are not use internet services
df_no__internet_service=df_internet_service.loc[df_internet_service['OnlineSecurity']=='No internet service']

# %%
# 7% churned clients are not use internet services
countplot_ratio(x="Churn",data=df_no__internet_service)

# %%
## 78.33% clients use internet services
df_yes__internet_service=df_internet_service.loc[df_internet_service['InternetService']!='No']
df_yes__internet_service.shape
# Out:
# (5512, 8)

# %%
# 31.83% churned clients use internet services
countplot_ratio(x="Churn",data=df_yes__internet_service)

# %%
df_internet_service[["OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies"]]=="Yes"
# Out:
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              False          True             False        False
# 1               True         False              True        False
# 2               True          True             False        False
# 3               True         False              True         True
# 4              False         False             False        False
# ...              ...           ...               ...          ...
# 7038            True         False              True         True
# 7039           False          True              True        False
# 7040            True         False             False        False
# 7041           False         False             False        False
# 7042            True         False              True         True
#
#       StreamingTV  StreamingMovies
# 0           False            False
# 1           False            False
# 2           False            False
# ...

# %%
#5.1% clients use internet services that use all services
df_all_internet_services=df_yes__internet_service.query('(OnlineSecurity == "Yes") and (OnlineBackup == "Yes") and (DeviceProtection == "Yes") and (TechSupport == "Yes") and (StreamingTV == "Yes") and (StreamingMovies == "Yes")')
df_all_internet_services.shape
# Out:
# (284, 8)

# %%
df_all_internet_services
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 15       Fiber optic            Yes          Yes              Yes         Yes
# 28               DSL            Yes          Yes              Yes         Yes
# 140              DSL            Yes          Yes              Yes         Yes
# 153              DSL            Yes          Yes              Yes         Yes
# 167              DSL            Yes          Yes              Yes         Yes
# ...              ...            ...          ...              ...         ...
# 6859     Fiber optic            Yes          Yes              Yes         Yes
# 6873             DSL            Yes          Yes              Yes         Yes
# 6910     Fiber optic            Yes          Yes              Yes         Yes
# 6995             DSL            Yes          Yes              Yes         Yes
# 7007             DSL            Yes          Yes              Yes         Yes
#
# ...

# %%
(df_all_internet_services.shape[0] /df_yes__internet_service.shape[0] )*100
# Out:
# 5.152394775036284

# %%
#Approximately 5.28% churned clients are  use all internet services
countplot_ratio(x="Churn",data=df_all_internet_services)

# %%
df_yes__internet_service
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# 1                DSL            Yes           No              Yes          No
# 2                DSL            Yes          Yes               No          No
# 3                DSL            Yes           No              Yes         Yes
# 4        Fiber optic             No           No               No          No
# ...              ...            ...          ...              ...         ...
# 7038             DSL            Yes           No              Yes         Yes
# 7039     Fiber optic             No          Yes              Yes          No
# 7040             DSL            Yes           No               No          No
# 7041     Fiber optic             No           No               No          No
# 7042     Fiber optic            Yes           No              Yes         Yes
#
# ...

# %%
(df_yes__internet_service['OnlineSecurity']=='Yes').sum()
# Out:
# 2019

# %%
(df_yes__internet_service['OnlineBackup']=='Yes').sum()
# Out:
# 2429

# %%
(df_yes__internet_service['DeviceProtection']=='Yes').sum()
# Out:
# 2422

# %%
(df_yes__internet_service['TechSupport']=='Yes').sum()
# Out:
# 2044

# %%
(df_yes__internet_service['StreamingTV']=='Yes').sum()
# Out:
# 2707

# %%
#Approximately 50% clients use internet services that use Streaming Movies ,Streaming Movies is most used in Internet Services 
((df_yes__internet_service['StreamingMovies']=='Yes').sum() / df_yes__internet_service.shape[0])*100
# Out:
# 49.519666485408735

# %%
df_yes__internet_service.iloc[10,:]
# Out:
# InternetService     DSL
# OnlineSecurity      Yes
# OnlineBackup         No
# DeviceProtection     No
# TechSupport          No
# StreamingTV          No
# StreamingMovies      No
# Churn                No
# Name: 10, dtype: object

# %%
def number_of_internet__services(row):
    s=0
    if row.OnlineSecurity == "Yes" :
        s+=1
    if row.OnlineBackup == "Yes" :
        s+=1
    if row.DeviceProtection == "Yes" :
        s+=1
    if row.TechSupport == "Yes" :
        s+=1
    if row.StreamingTV == "Yes" :
        s+=1
    if row.StreamingMovies == "Yes" :
        s+=1
    if (row.InternetService == "DSL"or row.InternetService == "Fiber optic") :
        s+=1
    return s
      
    
x=number_of_internet__services(df_yes__internet_service.iloc[10,:])
x
# Out:
# 2

# %%
df_internet_service['numberOfServices']= df_internet_service.apply(number_of_internet__services, axis=1)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_internet_service
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# 1                DSL            Yes           No              Yes          No
# 2                DSL            Yes          Yes               No          No
# 3                DSL            Yes           No              Yes         Yes
# 4        Fiber optic             No           No               No          No
# ...              ...            ...          ...              ...         ...
# 7038             DSL            Yes           No              Yes         Yes
# 7039     Fiber optic             No          Yes              Yes          No
# 7040             DSL            Yes           No               No          No
# 7041     Fiber optic             No           No               No          No
# 7042     Fiber optic            Yes           No              Yes         Yes
#
# ...

# %%
df_internet_service['numberOfServices'].plot.hist()

# %%
df_yes__internet_service['numberOfServices']= df_yes__internet_service.apply(number_of_internet__services, axis=1)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_yes__internet_service['numberOfServices'].plot.hist()

# %%
sns.swarmplot(x=data["InternetService"],y=data['TotalCharges'])

# %%
# clients use internet services that use 4 Services are higher range in TotalCharges 
sns.swarmplot(x=df_internet_service['numberOfServices'],y=data['TotalCharges'])

# %%
df_yes__internet_service['numberOfServices'].value_counts()
# Out:
# 4    1118
# 3    1033
# 2     966
# 5     852
# 1     693
# 6     571
# 7     284
# Name: numberOfServices, dtype: int64

# %%
df_internet_service['numberOfServices'].value_counts()
# Out:
# 0    1526
# 4    1118
# 3    1033
# 2     966
# 5     852
# 1     693
# 6     571
# 7     284
# Name: numberOfServices, dtype: int64

# %%
#20 % clients use internet services that use 4 Services
(df_internet_service['numberOfServices'].value_counts().iloc[1]/df_yes__internet_service.shape[0])*100
(df_yes__internet_service['numberOfServices'].value_counts().iloc[0]/df_yes__internet_service.shape[0])*100
# Out:
# 20.264636577850283

# %%
countplot_ratio(x='numberOfServices',data=df_internet_service,hue="Churn")

# %%
sns.countplot(x=data['tenure'],data=data)

# %%
sns.distplot(a=data['tenure'],kde=False)

# %%
sns.kdeplot(data=data['tenure'],shade=True)

# %%
x=pd.IntervalIndex.from_tuples([(-1,6),(6,12),(12,18),(18,24),(24,30),(30,36),(36,42),(42,48),(48,54),(54,60),(60,66),(66,72)])

# %%
data['tenure'].unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39], dtype=int64)

# %%
data['tenure'].plot.hist(x=range(6,73,6))

# %%
data['TotalCharges']= pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
data['TotalCharges'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
data['TotalCharges'].plot.hist()

# %%
sns.boxplot(data['TotalCharges'])

# %%
data['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
data['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
data['MonthlyCharges'].plot.hist()

# %%
sns.boxplot(data['MonthlyCharges'])

# %%
data.groupby('tenure').sum()
# Out:
#         SeniorCitizen  MonthlyCharges  TotalCharges
# tenure
# 0                   0          455.60          0.00
# 1                  86        30947.80      30947.80
# 2                  43        13615.10      27211.10
# 3                  25        11603.00      34938.00
# 4                  26        10108.15      40573.40
# ...               ...             ...           ...
# 68                 13         7332.10     500630.00
# 69                 13         6728.20     463223.95
# 70                 17         9089.10     636537.80
# 71                 31        12535.05     890559.65
# 72                 56        29211.90    2104105.10
#
# [73 rows x 3 columns]

# %%
data[['MonthlyCharges','tenure']].corr()
# Out:
#                 MonthlyCharges  tenure
# MonthlyCharges          1.0000  0.2479
# tenure                  0.2479  1.0000

# %%
sns.kdeplot(data=data['MonthlyCharges'],label='MonthlyCharges',shade=True)
sns.kdeplot(data=data['TotalCharges'],label='TotalCharges',shade=True)
plt.title("Distribution of Charges")

plt.legend()

# %%
sns.scatterplot(x='tenure',y='TotalCharges',data=data)

# %%
sns.regplot(x='tenure',y='TotalCharges',data=data)

# %%
sns.scatterplot(x='tenure',y='TotalCharges',hue="Churn",data=data)

# %%
sns.lmplot(x='tenure',y='TotalCharges',hue="Churn",data=data)

# %%
data[['TotalCharges','tenure']].corr()
# Out:
#               TotalCharges   tenure
# TotalCharges       1.00000  0.82588
# tenure             0.82588  1.00000

# %%
sns.heatmap(data.corr(), annot = True)

# %%
data.boxplot(figsize=(30,6), fontsize=20)
